# %% [markdown]
# # **libraries instalation**

# %%
# !pip install pytc2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
# ...

# %% [markdown]
# # **Libraries**

# %%
# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np


# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

# %% [markdown]
# 1.  Obtener la función transferencia V2V1
#   :  módulo , fase y diagrama de polos y ceros.

# %% [markdown]
# ![tarea0_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tarea0_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2.  Proponga una norma de frecuencia e impedancia  de forma tal de llegar a una transferencia normalizada

# %% [markdown]
# ![tarea0_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3.  Simule la transferencia normalizada en Python.
#
# obs: la magnitud es de 1x10^-15, en otras palabras es cero

# %%
w0 = 1
qq = 0

my_tf = TransferFunction( [1, -w0], [1, +w0] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq))
pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (2, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# 4. Simule la red en LTspice y obtenga su respuesta en frecuencia.
#
# se supuso que R2 Y R1 son el doble de R3, dado en la noramlizacion 2.

# %% [markdown]
# ![tarea0_4.png](data:image/png;base64,...)

# %% [markdown]
# ![tarea0_5.png](data:image/png;base64,...)

# %% [markdown]
# 5. ¿ Que tipo de filtro es ? Analizar el caso del MF-103  ¿ Utiliza la misma red ?
#
# en respuesta a la primer pregunta se trata de un fultro pasa todo, perimte el paso de todas las frecceuncias sin alterar su magnitud(en otras palabras no tiene ganancia alguna) pero si generando un cambio de fase.

# %% [markdown]
# En respuesta a la segunda pregunta, a mi entender actual no, segun lo investigado la pregunta refiere a la ultima hoja del pdf del MF-103, que es un coneccionado de filtros pasa todo en cascada. si bien ambos filtros son pasa todo, no estarian en principio teniendo la masima red.

# %% [markdown]
# referencias: [Classification of Phaser pedals according to their stages.](https://www.reddit.com/r/guitarpedals/comments/1g9pi9m/classification_of_phaser_pedals_according_to/#:~:text=A%20stage%20is%20an%20all,across%20a%20certain%20frequency%20range.)
