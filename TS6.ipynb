# %% [markdown]
# # Tarea semanal 6

# %% [markdown]
# ![image.png](attachment:e6be9cbe-688b-4a8b-b04c-7b69773c19f7.png)
# ### 1. Obtenga un solo juego de parámetros en forma analítica para cada caso:  Z,Y ó ABCD
# ![UNO](images/TS6_-1.png)
# ![UNO](images/TS6_-2.png)
# ![UNO](images/TS6_-3.png)
# ### 2. Aplicar transformación de parámetros para hallar los Z,Y  si lo obtenido fue ABCD ó viceversa.
# ![UNO](images/TS6_-4.png)
# ![UNO](images/TS6_-5.png)

# %% [markdown]
# # BONUS
# ![image.png](attachment:98961268-65b9-4988-9bb5-72840120b71d.png)
# ![image.png](attachment:d21021d5-97dc-4856-9f9c-ce3083a076d3.png)
# ![image.png](attachment:f7001b31-fe52-471b-8cec-a59008b8d947.png)
