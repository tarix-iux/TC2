# %% [markdown]
# # Tarea Semanal 4

# %% [markdown]
# ## 1. Utilizando el método de Storch ( pag. 403 del Schaumann ) obtener la T(s)  Bessel de orden N = 2, 3 y 4
#
# ![uno](images/TS4_1.png)

# %% [markdown]
# ## 2. Elegir la T(s) con el mínimo orden que cumple con αmáx=1dB
# El metodo propuesto para resolver esto es analizar el modulo de la inversa de las $ T(s) $ antes econtradas, evaluando en $ J W_p $
# ![uno](images/TS4_3.png)
# Se encuentra que la primer $ T(s) $ que cumple lo pedido es la de $ n=3 $
#
# $$
# T(s) = \frac{ 15 }{ s^3 + s^2 \cdot 6 + s \cdot 15 + 15}
# $$
#
# Como paso adicional para un algebra mas facil, se factoriza la expresion llegando a:
#
# $$
# T(s) ≈ \frac{ 2.5361^2 }{ s^2 + s \cdot 3.6778 + 6.459} \cdot \frac{2.3221}{s + 2.3221}
# $$

# %% [markdown]
# ## 3. Evaluar el Retardo de Grupo  D(2.5). Expresar en forma porcentual [%] el error o desviamiento respecto a D(0)
# ![uno](images/TS4_4.png)
# ![uno](images/TS4_5.png)
# ![uno](images/TS4_6.png)

# %% [markdown]
# ## 4. Sintetizar el circuito normalizado con estructuras Sallen-Key con K=1 ( real. negativa unitaria )
# ![uno](images/TS4_7.png)
# ![uno](images/TS4_8.png)
# ![uno](images/TS4_9.png)
# ![uno](images/TS4_10.png)

# %% [markdown]
# # BONUS

# %%
from pytc2.sistemas_lineales import pretty_print_lti

num = [135]
den = [1, 10, 55, 135, 135]

pretty_print_lti(num, den)
# Out:
# $\displaystyle \frac{135 }{s^4 + s^3 \,\,  10 + s^2 \,\,  55 + s \,\, 135 + 135 }$

# %% [markdown]
# (El bonus 2 fue resueltro arriba)
# ![image.png](attachment:09f8d576-4489-40b8-84c5-bcf0fda9fce0.png)
#
# ### Se puede ver que el cursor uno, en 10mHz, da un D = 199.99µs y el otro cursor puesto en -3db da D = 186.53µs. Dando un ΔD(w) de 13.5µs
